# %% [markdown]
# ## 1D Fiting with SASView from notebook
# ## prism model template notebook
# ## with 1D assembly side by side of N particles

# %% [markdown]
# * import all the packages
# * install packages before using a separate notebook
# * better to work in a dedicated python environnement

# %%
import numpy as np

import sasmodels
import sasmodels.core
import sasmodels.data
import sasmodels.bumps_model

import sasdata

from sasdata.dataloader.loader import Loader
from sasmodels.data import load_data
from sasmodels.data import plot_theory

import bumps
import bumps.fitters
import bumps.names
import bumps.fitproblem

import os

# %% [markdown]
# * configuration of matplotlib for plots

# %%
"""
import matplotlib.pyplot and set custom default settings for plots
"""
# %matplotlib inline
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

import matplotlib.pyplot as plt

plt.rc('font', size=14) 
plt.rc('axes', titlesize=16)
plt.rc('axes', labelsize=16)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('legend', fontsize=14)
plt.rc('legend', title_fontsize=14)
plt.rc('figure', titlesize=18)
plt.rc("figure", figsize=(5,5))
plt.rc("lines", linewidth=3)

# %% [markdown]
# * example of checking the version of a SASView packages

# %%
sasdata.__version__
# Out:
# '0.11.0'

# %%
sasmodels.__version__
# Out:
# '1.1.0a2.dev4+ge63cb8e84'

# %% [markdown]
# ### Load a 1D data file

# %% [markdown]
# * load an experimental data file .dat
# * define here filename and path on your computer

# %%
filename='./data-examples/PR8_50mM8A2_01302{00000}_AzInt_Px_399_sub.dat'

# %% [markdown]
# Process the data file:
# * use `skiheader` to skip the header
# * use `skipmin` to skip data points at low q values
# * use `skipmax` to skip data points at large q values
# * load the data in a numpy array and show a first plot
# * use `slicing_step` to reduce the number of data points (slicing_step=3 means that 1 point over 3 is taken)
# * use `rescale` the intensity coefficient for rescaling (in cm-1) if not done previously
# * use `coeff` to compute realistic error bars as a percentage of intensity values (coeff=0.1 means 10% of intensity error bars)
# * transform the numpy array into a suitable 1D data set using `sasmodels.data.Data1D`
# * data plot shows the complete data `data_np` set and the new one `data`

# %%
#number of lines in the header
skipheader=4

data_np = np.loadtxt(filename, skiprows=skipheader)

total_data_number=data_np.shape[0] #total number of data points in the file
print('total number of data points: ',total_data_number)

plt.loglog(data_np[:,0], data_np[:,1], '+')

#number of points to skip at low q values
skipmin=0
data_np = np.loadtxt(filename, skiprows=skipheader+skipmin)

# number of data point to skip at the end
skipmax=600
number_of_data=total_data_number-skipmax-skipmin

print('after skip at low and large q values:', number_of_data)

slicing_step=2 # step of slicing 

# rescaling of intensity values
# TP UE soft matter 2026
# scaling factor from SWING to Cu-SAXS to be in cm-1
rescale=1

# new error bars: 10 % of intensity values
coeff=0.1

data = sasmodels.data.Data1D(x=data_np[0:number_of_data:slicing_step,0], 
                             y=rescale*data_np[0:number_of_data:slicing_step,1], 
                             dy=rescale*coeff*abs(data_np[0:number_of_data:slicing_step,1]))

number_of_data_new=data.x.shape[0]
print('after slicing:', number_of_data_new)

sasmodels.data.plot_data(data)
# Out:
# total number of data points:  1206
# after skip at low and large q values: 606
# after slicing: 303

# %% [markdown]
# * plot of the new data set `data`

# %%
sasmodels.data.plot_data(data)

# %% [markdown]
# ### save `data` in a new data file
# * add `_new`at the end of the name

# %%
newfilename=filename[:-4]+"_new.dat" # data 

with open(newfilename, "w") as f:
    f.write("raw data file is:"+filename+"\n")
    f.write("number of data points: \t"+str(number_of_data_new)+"\n")

with open(newfilename, "a") as fa:
    for i in range(0,number_of_data_new):
        line_to_write=str(data.x[i])+"\t"+str(data.y[i])+"\t"+str(data.dy[i])+"\n"
        fa.write(line_to_write)

# %% [markdown]
# ### fit the data

# %% [markdown]
# * create the computation `kernel` selecting the `cylinder` model
# * create the `model` interfaced with bump module
# * create the `experiment`, containing both data and model

# %%
kernel = sasmodels.core.load_model("assembly_1D_prism")
params = {} # default parameters for now
model = sasmodels.bumps_model.Model(kernel, **params)
experiment = sasmodels.bumps_model.Experiment(data=data, model=model)

# %% [markdown]
# * default values of all parameters

# %%
kernel.info.parameters.defaults
# Out:
# {'scale': 1,
#  'background': 0.001,
#  'sld': 126.0,
#  'sld_solvent': 9.4,
#  'n_sides': 5,
#  'radius_average': 500,
#  'length': 5000,
#  'a_lattice': 100,
#  'n_size': 10}

# %% [markdown]
# #### preliminary step: manual adjustment of parameters before fiting

# %% [markdown]
# Don't forget updating the SLD values (x10-6 A-2) !
# * gold: 125
# * silver: 77.9
# * water: 9.47
# * toluene: 8.4

# %%
sld_gold=125
sld_silver=77.9
sld_water=9.47
sld_toluene=8.4

# %%
kernel = sasmodels.core.load_model("assembly_1D_prism")


params = {
    "n_sides": 5,
    "radius_average": 300,
    "radius_average_pd_type": 'gaussian', 
    "radius_average_pd": 0.01, 
    "radius_average_pd_n": 8, 
    "radius_average_pd_nsigma": 3,
    "length": 1170,
    "length_pd_type": 'gaussian', 
    "length_pd": 0.05, 
    "length_pd_n": 8, 
    "length_pd_nsigma": 3,
    
     
    "sld": sld_gold,         
    "sld_solvent": sld_water,
    "background": 0.000000,
    "scale": 0.000003,

    "a_lattice": 650,
    "n_size": 40,

}

model = sasmodels.bumps_model.Model(model=kernel, **params)
experiment = sasmodels.bumps_model.Experiment(data=data, model=model)

plt.figure(figsize=(10,5))

experiment.plot()

# %% [markdown]
# ### Explanation of the polydispersity parameters

# %% [markdown]
# The polydispersity is set using a special set of \*\_pd\_\* parameters:
# * `*_pd*` is the width of the polydispersity and the exact definition will depend on the type of distribution specified; in this cause of a 'gaussian` distribution, it is defined as as $\frac{\sigma}{x_{mean}}$
# * `*_pd_type*` defines the type of polydispersity distribution used
# * `*_pd_n` corresponds to the the number of points in the distribution used by the calculation (Npts in the image below)
# * `*_pd_nsigma` sets the range of the distribution sampled (Nsigmas in the image below)
#
# For example, radius polydispersity could be defined by specifying **all four** of the pd parameters. With the default values, this would look like:
# * `radius_pd = 0`
# * `radius_pd_type = 'gaussian'`
# * `radius_pd_n = 35`
# * `radius_pd_nsigma = 3`
#
# The available polydispersity distributions are defined in the SasView [documentation](https://www.sasview.org/docs/user/qtgui/Perspectives/Fitting/pd/polydispersity.html) but we can access them directly through the sasmodels `weights` module.
#
# The 'gaussian' distribution is claculed by:
#
# $$
# f(x) = \frac{1}{Norm}\exp\left(-\frac{(x-x_{mean})^2}{2\sigma^2}\right)
# $$
#
# <img src=https://www.sasview.org/docs/_images/pd_gaussian.jpg>
#
# *Image source: https://www.sasview.org/docs/user/qtgui/Perspectives/Fitting/pd/polydispersity.html*

# %% [markdown]
# ## fiting the data

# %% [markdown]
# * choice of the initial values for parameters
# * choice of the fiting parameters with their fiting range

# %%
model = sasmodels.bumps_model.Model(model=kernel, **params)


model.scale.range(0.00000001,0.00000005)      
model.background.range(1e-06, 1e-05)   
model.radius_average.range(280, 320)          
model.radius_average_pd.range(0.0, 0.03)
#model.length.range(1000, 1200)          
#model.length_pd.range(0.0, 0.2)

 

experiment = sasmodels.bumps_model.Experiment(data=data, model=model)

problem = bumps.fitproblem.FitProblem(experiment)

results = bumps.fitters.fit(problem, 
                            method='lm', 
                            steps=20,   
                            ftol=1.5e-06, 
                            xtol=1.5e-06, 
                            verbose=True)

plt.figure(figsize=(8,8))
print(problem.summarize())
print(model.state())
print(f"Chi-Squared: {problem.chisq()}")
sasmodels.data.plot_theory(data,experiment.Iq_calc)
# Out:
# c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\fitproblem.py:631: UserWarning: Unsatisfied constraints: [background=0.0 is outside (1e-06,1e-05),
# scale=3e-06 is outside (1e-08,5e-08)]
#   warnings.warn("Unsatisfied constraints: [%s]" % (",\n".join(broken)))
# step 1 cost 101.153(16)
#                               background |.........      1e-06 in [1e-06, 1e-05]
#                           radius_average ....|.....        300 in [280, 320]
#                        radius_average_pd ...|......       0.01 in [0, 0.03]
#                                    scale .........|      5e-08 in [1e-08, 5e-08]
# step 2 cost 101.151(16)
#                               background .........|      1e-05 in [1e-06, 1e-05]
#                           radius_average ....|.....    299.533 in [280, 320]
#                        radius_average_pd ...|......  0.0114277 in [0, 0.03]
#                                    scale .........|      5e-08 in [1e-08, 5e-08]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 17
#      13 experiment = sasmodels.bumps_model.Experiment(data=data, model=model)
#      15 problem = bumps.fitproblem.FitProblem(experiment)
# ---> 17 results = bumps.fitters.fit(problem,
#      18                             method='lm',
#      19                             steps=20,
#      20                             ftol=1.5e-06,
#      21                             xtol=1.5e-06,
#      22                             verbose=True)
#      24 plt.figure(figsize=(8,8))
#      25 print(problem.summarize())
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\fitters.py:1463, in fit(problem, method, export, resume, store, name, verbose, parallel, **options)
#    1461 if resume is not None:
#    1462     problem.setp(resume.x)
# -> 1463 x, fx = driver.fit(fit_state=None if resume is None else resume.state)
#    1464 problem.setp(x)
#    1465 if verbose:
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\fitters.py:1119, in FitDriver.fit(self, resume, fit_state)
#    1115 self.fitter = fitter
#    1116 self.monitor_runner = MonitorRunner(
#    1117     problem=self.problem, monitors=self.monitors, abort_test=self.abort_test, max_time=self.max_time
#    1118 )
# -> 1119 x, fx = fitter.solve(
#    1120     monitors=self.monitor_runner, abort_test=self.abort_test, mapper=self.mapper, **self.options
#    1121 )
#    1122 if x is not None:
#    1123     self.problem.setp(x)
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\fitters.py:673, in MPFit.solve(self, monitors, mapper, **options)
#     670     if monitors.stopping():
#     671         return -1
# --> 673 result = mpfit(
#     674     fcn=self._residuals,
#     675     xall=x0,
#     676     parinfo=parinfo,
#     677     autoderivative=True,
#     678     fastnorm=True,
#     679     double=0,  # use single precision machine epsilon for derivative step
#     680     # damp=0,  # no damping when damp=0
#     681     # Stopping conditions
#     682     ftol=options["ftol"],
#     683     xtol=options["xtol"],
#     684     # gtol=1e-100, # exclude gtol test
#     685     maxiter=options["steps"],
#     686     # Progress monitor
#     687     iterfunct=update,
#     688     nprint=1,  # call monitor each iteration
#     689     quiet=True,  # leave it to monitor to print any info
#     690     # Returns values
#     691     nocovar=True,  # use our own covar calculation for consistency
#     692 )
#     693 # Note that result.perror contains dx and result.covar contains cov.
#     694 # See mpfit.py:781 for status codes. We are returning -1 for user abort.
#     695 if result.status > 0 or result.status == -1:
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\mpfit.py:1083, in mpfit.__init__(self, fcn, xall, functkw, parinfo, ftol, xtol, gtol, damp, maxiter, factor, nprint, iterfunct, iterkw, nocovar, fastnorm, rescale, autoderivative, quiet, diag, epsfcn, debug, double)
#    1081 self.status = 2
#    1082 catch_msg = "calling MPFIT_FDJAC2"
# -> 1083 fjac = self.fdjac2(
#    1084     fcn,
#    1085     x,
#    1086     fvec,
#    1087     step,
#    1088     qulim,
#    1089     ulim,
#    1090     dside,
#    1091     epsfcn=epsfcn,
#    1092     autoderivative=autoderivative,
#    1093     dstep=dstep,
#    1094     functkw=functkw,
#    1095     ifree=ifree,
#    1096     xall=self.params,
#    1097 )
#    1098 if fjac is None:
#    1099     self.errmsg = "WARNING: premature termination by FDJAC2"
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\mpfit.py:1623, in mpfit.fdjac2(self, fcn, x, fvec, step, ulimited, ulimit, dside, epsfcn, autoderivative, functkw, xall, ifree, dstep)
#    1621 xp = xall.copy()
#    1622 xp[ifree[j]] = xp[ifree[j]] + h[j]
# -> 1623 [status, fp] = self.call(fcn, xp, functkw)
#    1624 if status < 0:
#    1625     return None
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\mpfit.py:1491, in mpfit.call(self, fcn, x, functkw, fjac)
#    1489 self.nfev = self.nfev + 1
#    1490 if fjac is None:
# -> 1491     [status, f] = fcn(x, fjac=fjac, **functkw)
#    1492     if self.damp > 0:
#    1493         ## Apply the damping if requested.  This replaces the residuals
#    1494         ## with their hyperbolic tangent.  Thus residuals larger than
#    1495         ## DAMP are essentially clipped.
#    1496         f = numpy.tanh(f / self.damp)
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\fitters.py:721, in MPFit._residuals(self, p, fjac)
#     717 # Tally costs for residuals and broken constraints. Treat prior probabilities on
#     718 # the parameters and broken constraints as additional measurements. The result
#     719 # should be that fnorm = sumsq residuals = 2 * nllf
#     720 extra_cost, failing_constraints = self.problem.constraints_nllf()
# --> 721 residuals = np.hstack((self.problem.residuals().flat, self.problem.parameter_residuals(), np.sqrt(extra_cost)))
#     722 # print("sumsq resid", np.sum(residuals**2), "nllf", self.problem.nllf()*2)
#     723
#     724 # # Spread the cost over the residuals.  Since we are smoothly increasing
#     725 # # residuals as we leave the boundary, this should push us back into the
#     726 # # boundary (within tolerance) during the lm fit.
#     727 # residuals += np.sign(residuals) * (extra_cost / len(residuals))
#     728 return 0, residuals
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\bumps\fitproblem.py:724, in FitProblem.residuals(self)
#     723 def residuals(self):
# --> 724     resid = np.hstack([w * f.residuals() for w, f in zip(self.weights, self.models)])
#     725     return resid
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\bumps_model.py:271, in Experiment.residuals(self)
#     265 """
#     266 Return theory minus data normalized by uncertainty.
#     267 """
#     268 # if np.any(self.err ==0): print("zeros in err")
#     269 # from bumps.fitproblem import fitness_show_parameters
#     270 # if any(np.isnan(self.theory())): (print("nan in theory for:"),fitness_show_parameters(self))
# --> 271 return (self.theory() - self.Iq) / self.dIq
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\bumps_model.py:260, in Experiment.theory(self)
#     258 if 'theory' not in self._cache:
#     259     pars = self.model.state()
# --> 260     self._cache['theory'] = self._calc_theory(pars, cutoff=self.cutoff)
#     261 return self._cache['theory']
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\direct_model.py:338, in DataMixin._calc_theory(self, pars, cutoff)
#     335 pars = pars.copy()
#     336 pars['background'] = 0.
# --> 338 Iq_calc = call_kernel(self._kernel, pars, cutoff=cutoff)
#     339 self.results = getattr(self._kernel, 'results', None)
#     340 # Storing the calculated Iq values so that they can be plotted.
#     341 # Only applies to oriented USANS data for now.
#     342 # TODO: extend plotting of calculate Iq to other measurement types
#     343 # TODO: refactor so we don't store the result in the model
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\direct_model.py:59, in call_kernel(calculator, pars, cutoff, mono)
#      57 call_details, values, is_magnetic = make_kernel_args(calculator, mesh)
#      58 #print("in call_kernel: values:", values)
# ---> 59 return calculator(call_details, values, cutoff, is_magnetic)
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\kernel.py:94, in Kernel.Iq(self, call_details, values, cutoff, magnetic)
#      80 def Iq(self, call_details, values, cutoff, magnetic):
#      81     # type: (CallDetails, np.ndarray, np.ndarray, float, bool) -> np.ndarray
#      82     r"""
#      83     Returns I(q) from the polydisperse average scattering.
#      84
#    (...)     92     built into the model, and do not need an additional scale.
#      93     """
# ---> 94     _, F2, _, shell_volume, _ = self.Fq(call_details, values, cutoff,
#      95                                         magnetic, radius_effective_mode=0)
#      96     combined_scale = values[0]/shell_volume
#      97     background = values[1]
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\kernel.py:169, in Kernel.Fq(self, call_details, values, cutoff, magnetic, radius_effective_mode)
#     101 def Fq(self, call_details, values, cutoff, magnetic,
#     102        radius_effective_mode=0):
#     103     # type: (CallDetails, np.ndarray, np.ndarray, float, bool, int) -> np.ndarray
#     104     r"""
#     105     Returns <F(q)>, <F(q)^2>, effective radius, shell volume and
#     106     form:shell volume ratio.  The <F(q)> term may be None if the
#    (...)    167     hollow and solid shapes.
#     168     """
# --> 169     self._call_kernel(call_details, values, cutoff, magnetic,
#     170                       radius_effective_mode)
#     171     #print("returned",self.q_input.q, self.result)
#     172     nout = 2 if self.info.have_Fq and self.dim == '1d' else 1
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\kernelpy.py:197, in PyKernel._call_kernel(self, call_details, values, cutoff, magnetic, radius_effective_mode)
#     193 #print("Calling python kernel")
#     194 #call_details.show(values)
#     195 radius = ((lambda: 0.0) if radius_effective_mode == 0
#     196           else (lambda: self._radius(radius_effective_mode)))
# --> 197 self.result = _loops(
#     198     self._parameter_vector, self._form, self._volume, radius,
#     199     self.q_input.nq*self._nq_copies, call_details, values, cutoff)
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\kernelpy.py:283, in _loops(parameters, form, form_volume, form_radius, nq, call_details, values, cutoff)
#     277 p0_index += 1
#     278 if weight > cutoff:
#     279     # Call the scattering function.
#     280     # Assume that NaNs are only generated if the parameters are bad;
#     281     # exclude all q for that NaN.  Even better would be to have an
#     282     # INVALID expression like the C models, but that is expensive.
# --> 283     Iq = np.asarray(form(), 'd')
#     284     if np.isnan(Iq).any():
#     285         continue
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\kernelpy.py:174, in PyKernel.__init__.<locals>.<lambda>()
#     172     else:
#     173         form = model_info.Iq
# --> 174         self._form = lambda: form(q, *kernel_args)
#     175         self._nq_copies = 1
#     177 # Generate a closure which calls the form_volume if it exists.
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\models\assembly_1D_prism.py:421, in Iq(q, sld, sld_solvent, n_sides, radius_average, length, npoints_fibonacci)
#     419 qc = q[:, np.newaxis] * q_unit[:, 2][np.newaxis, :]
#     420 # # Compute intensity
# --> 421 intensity = Iqabc(qa.ravel(), qb.ravel(), qc.ravel(), n_sides, radius_average, length).reshape(qa.shape)
#     422 # Uniform average over the sphere
#     423 integral = np.mean(intensity, axis=1)
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\models\assembly_1D_prism.py:389, in Iqabc(qa, qb, qc, n_sides, radius_average, length)
#     371 """
#     372 Calls the function that computes the edge length and the scattered intensity.
#     373 Parameters
#    (...)    386     Scattered intensity of the nanoprism at the specific three dimensional q components.
#     387 """
#     388 n_sides = int(n_sides)
# --> 389 A = Fqabc(qa, qb, qc, n_sides, radius_average, length)
#     390 intensity = (np.abs(A))**2  # intensity is proportional to volume
#     391 return intensity
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\models\assembly_1D_prism.py:366, in Fqabc(qa, qb, qc, n_sides, radius_average, length)
#     364 vertices = shape_generator(n_sides,radius)
#     365 perpendicular_factor_value = sas_sinx_x(qc*length/2) * length
# --> 366 parallel_factor_value = parallel_factor(vertices,qab,0.)
#     367 A = parallel_factor_value * perpendicular_factor_value
#     368 return A
#
# File c:\Users\IMPÉROR\CloudStation\dev-SASView\.venv\Lib\site-packages\sasmodels\models\assembly_1D_prism.py:339, in parallel_factor(vertices, q, c)
#     337     #The exp(iqRj) is rewritten as a sum of cos+isin because of the way math.exp() works (not allowing complex as input)
#     338     qRj = np.dot(q, edgecenters[:,i])
# --> 339     sum += triple_product * (sas_sinx_x(qEj)*(np.cos(qRj)+np.sin(qRj)*1J)-c)
#     340 return (2/(1J*qmodulus2_cutoff)*sum)
#
# KeyboardInterrupt:

# %% [markdown]
# The current value of all parameters can always be called using `model.state()`:

# %%
print(model.state())
print(problem.summarize())
print(problem.chisq())
# Out:
# {'scale': 2.3341425525983055e-08, 'background': 2.930302925433074e-06, 'sld': 125.0, 'sld_solvent': 9.47, 'n_sides': 5.0, 'n_sides_pd': 0.0, 'n_sides_pd_n': 35.0, 'n_sides_pd_nsigma': 3.0, 'radius_average': 296.944687576168, 'radius_average_pd': 0.03, 'radius_average_pd_n': 8.0, 'radius_average_pd_nsigma': 3.0, 'length': 1170.0, 'length_pd': 0.05, 'length_pd_n': 8.0, 'length_pd_nsigma': 3.0, 'up_frac_i': 0.0, 'up_frac_f': 0.0, 'up_theta': 90.0, 'up_phi': 0.0, 'sld_M0': 0.0, 'sld_mtheta': 0.0, 'sld_mphi': 0.0, 'sld_solvent_M0': 0.0, 'sld_solvent_mtheta': 0.0, 'sld_solvent_mphi': 0.0, 'n_sides_pd_type': 'gaussian', 'radius_average_pd_type': 'gaussian', 'length_pd_type': 'gaussian'}
#                               background ..|....... 2.9303e-06 in [1e-06, 1e-05]
#                           radius_average ....|.....    296.945 in [280, 320]
#                        radius_average_pd .........|       0.03 in [0, 0.03]
#                                    scale ...|...... 2.33414e-08 in [1e-08, 5e-08]
# 0.9817971441624265

# %% [markdown]
# * store the fited values in R_fit and L_fit

# %%
# value of R after fiting
R_fit=model.radius_average.value

# value of Thickness after fiting (Replaces L_fit)
T_fit=model.length.value

# %% [markdown]
# #### Save the fited curve in a file
# * `_fit` is added at the end of filename

# %%
fitfilename=filename[:-4]+"_fit.dat" # fit 

with open(fitfilename, "w") as f:
    f.write("raw data file is:"+filename+"\n")
    f.write("number of data points: \t"+str(number_of_data_new)+"\n")

with open(fitfilename, "a") as fa:
    for i in range(0,number_of_data_new-1):
        line_to_write=str(data.x[i])+"\t"+str(experiment.Iq_calc[i])+"\n"
        fa.write(line_to_write)

# %%
results.x
# Out:
# array([2.93030293e-06, 2.96944688e+02, 3.00000000e-02, 2.33414255e-08])

# %%
results.dx
# Out:
# array([1.13275327e-07, 7.20614504e-01, 2.82277999e-03, 2.00819032e-10])

# %% [markdown]
# ### final plot
# * use this one for a nice .svg output

# %%
data_final = np.loadtxt(newfilename, skiprows=3)

fit_final = np.loadtxt(fitfilename, skiprows=3)

plt.loglog(data_final[:,0], data_final[:,1], 'o')
plt.loglog(fit_final[:,0], fit_final[:,1])
plt.xlabel('q '+r'(Å$^{-1}$)',fontsize=14)
plt.ylabel('I'+r'(cm$^{-1}$)',fontsize=14)
plt.text(0.005,0.8,r'$\chi^2$ = '+f"{problem.chisq():.2f}",fontsize=14,horizontalalignment='center')
print(problem.chisq())
# Out:
# 0.9817971441624265
